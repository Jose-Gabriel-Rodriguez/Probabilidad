# %% [markdown]
# <a href="https://colab.research.google.com/github/Jose-Gabriel-Rodriguez/Probabilidad/blob/main/Unidad4/PRO_U4_Practica_1_Distribucion_Normal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image](https://github.com/JoseGabriel-ITD/Probabilidad-y-Estadistica/blob/main/Cintilla2004.png?raw=true)
#
# # **Probabilidad y Estadística**
#
# ## Unidad 4. Distribuciones de Probabilidad
#
# ### Practica 1: Distribución Normal
#
# ### Facilitador: *Dr. José Gabriel Rodríguez Rivas*
#
# ### Alumno:  _____________

# %% [markdown]
# <div style="color: blue;">
# <h1> Practica 1: Distribución Normal </h1>
# </div>
#
# - **Aplica para variables aleatorias continuas, (número infinito de valores).**
# - La distribución normal, también conocida como distribución gaussiana, es una función matemática que describe la forma en que se distribuyen los datos en una población.
# - Se caracteriza por tener una forma de campana simétrica alrededor de su media, lo que significa que la mayoría de los datos se concentran alrededor de este valor central.
#
# ![image.png](attachment:image.png)
#
# ### Fórmula de densidad de probabilidad
#
# $$
# f(x) =\frac{1}{\sigma \cdot \sqrt{2 \cdot \pi}}\cdot e
# ^{\frac{-1}{2}\cdot ( \frac {x - \mu}{\sigma}) ^2}
# $$
#
# En donde:
# $π=3.14159$ y
# $e=2.71828$.
#
# ### Variable aleatoria X
# - Para «transformar» un valor de una variable X proveniente de una curva normal a su correspondiente valor Z (calificación Z) de una curva normal estándar, se utiliza la siguiente ecuación:
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# En python se pueden utilizar las siguientes funciones para tratar con una distribución normal:
#
# - **norm.rvs()** para calcular números aleatorios.
# - **norm.pdf()** para calcular la densidad.
# - **norm.cdf()** para calcular la probabilidad acumulada.
# - **norm.ppf()** para calcular el valor de la a partir de una probabilidad, es la función inversa de cdf().

# %% [markdown]
# ## Ejercicio 1
#
# Una revision de los pesos de 500 estudiantes del ITD, evidenció que la **media es de 70 kilogramos** y la **desviación estandar es de 4 kilogramos**. Suponiendo que los valores se distribuyen normalmente. Hallar lo siguiente:
#
# - Generar aleatoriamente las edades de los 500 estudiantes con una media de 70 kg. y una desviación estandar de 4 kg.
# - Realizar un histogrma de las edades
# - Graficar la función de densidad de probabilidad (PDF).
#
# Fuente: https://www.youtube.com/watch?v=PKgk6wmM2FI

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# %%
# Generar datos para la distribución normal

media = 70  # Media
desv_std = 4 # Desviación estándar
num_datos = 500

# generamos los datos de manera aleatoria y lon ponemos en una lista (array)
datos = np.random.normal(media, desv_std, num_datos)
datos[0:50]  # Mostrar los primeros 50
# Out:
# array([66.89471118, 66.86697281, 69.08836516, 69.99997211, 69.26118637,
#        68.85257197, 77.02522456, 69.53712302, 76.42136176, 69.96667082,
#        70.30323537, 72.65276156, 70.75959978, 71.01072002, 73.29228391,
#        70.38260288, 69.66672762, 69.25634006, 68.63286205, 66.46211117,
#        67.67274611, 66.16811123, 66.97169285, 69.12045956, 67.6132534 ,
#        74.88685496, 70.2263685 , 66.2723357 , 69.44343792, 70.06480071,
#        77.70947133, 65.86178156, 66.0213366 , 67.10022937, 70.96949767,
#        77.44030368, 69.13480316, 64.31057045, 74.60793782, 72.17302979,
#        73.57214439, 69.32049276, 78.21416477, 71.60666096, 68.60033159,
#        64.88758683, 72.309075  , 73.98519833, 67.11468509, 70.94727258])

# %%
# Graficar histograma
plt.figure(figsize=(6, 4))
plt.hist(datos, bins=15, alpha=0.4, color='b')  # Histograma de los datos
plt.title('Distribución Normal ')
plt.xlabel('Peso en kg de los estudiantes')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Fórmula de la Funcion de densidad de probabilidad (PDF) de la distribución normal
#
# $$
# f(x) =\frac{1}{\sigma \cdot \sqrt{2 \cdot \pi}}\cdot e
# ^{\frac{-1}{2}\cdot ( \frac {x - \mu}{\sigma}) ^2}
# $$

# %%
# # Crear un rango de valores para crear una densidad
x = np.linspace(media - 3 * desv_std, media + 3 * desv_std, num_datos)

    # Calcular la PDF de la distribución normal
pdf = 1 / (desv_std * np.sqrt(2 * np.pi)) * np.exp(-(x - media)**2 / (2 * desv_std **2))

# %%
pdf.size, num_datos
# Out:
# (500, 500)

# %%
# Para no imprimir toda la lista de valores (500), desplegamos los primeros 50

print("Imprimir los primeros 50 Valores de x", x[0:50], " , y los primeros 50 pdf", pdf[0:50])
# Out:
# Imprimir los primeros 50 Valores de x [58.         58.04809619 58.09619238 58.14428858 58.19238477 58.24048096
#  58.28857715 58.33667335 58.38476954 58.43286573 58.48096192 58.52905812
#  58.57715431 58.6252505  58.67334669 58.72144289 58.76953908 58.81763527
#  58.86573146 58.91382766 58.96192385 59.01002004 59.05811623 59.10621242
#  59.15430862 59.20240481 59.250501   59.29859719 59.34669339 59.39478958
#  59.44288577 59.49098196 59.53907816 59.58717435 59.63527054 59.68336673
#  59.73146293 59.77955912 59.82765531 59.8757515  59.9238477  59.97194389
#  60.02004008 60.06813627 60.11623246 60.16432866 60.21242485 60.26052104
#  60.30861723 60.35671343]  , y los primeros 50 pdf [0.00110796 0.00114858 0.0011905  0.00123379 0.00127846 0.00132455
#  0.00137211 0.00142118 0.00147178 0.00152397 0.00157777 0.00163325
#  0.00169042 0.00174935 0.00181007 0.00187262 0.00193706 0.00200342
#  0.00207176 0.00214212 0.00221455 0.0022891  0.00236581 0.00244475
# ...

# %%
   # Visualizar la PDF
plt.figure(figsize=(6, 4))
plt.plot(x, pdf, label='Normal:(media:{}; ds:{})'.format(np.round(media, 2), np.round(desv_std, 2)))
plt.title('Función de Densidad de Probabilidad (PDF) - Distribución Normal')
plt.xlabel('Pesos en Kg. de los estudiantes')
plt.ylabel('Densidad de Probabilidad')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Poner todo junto

# %%
# Graficar histograma
plt.figure(figsize=(6, 4))
plt.hist(datos, bins=15, alpha=0.4, density=True, color='b')
plt.plot( x, pdf, 'k', linewidth=2, )

plt.title('Distribución Normal ')
plt.xlabel('Peso en kg de los estudiantes')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Ejercicio 2
#
# Una revision de los pesos de **500 estudiantes del ITD**, evidenció que la **media es de 70 kilogramos** y la **desviacion estandar es de 4 kilogramos**. Suponiendo que los valores se distribuyen normalmente.
# Hallar lo siguiente:
#
# - Cuantos estudiantes pesan menos de 75 kg.
# - Cuantos estudiantes pesan menos de 62 kg.
# - Cuantos estudiantes pesan mas de 79 kg.
#
# Primero necesitamos calcular la probabilidad de que un estudiante pese menos de 75 kg utilizando la función de distribución acumulativa (CDF) de la distribución normal

# %% [markdown]
#  ###  Cuantos estudiantes pesan menos de 75 kg.

# %%
plt.figure(figsize=(6, 4))

# Parámetros de la distribución normal
media = 70  # Media
desv_std = 4  # Desviación estándar
total_estudiantes = 500

# VARIABLE para Cálculo de la probabilidad de que un estudiante que pese menos de 75 kg
peso_limite = 75

# Primero necesitamos calcular la probabilidad de que un estudiante pese menos
# de 75 kg utilizando la función de distribución acumulativa (CDF) de la distribución normal
prob_menos_75kg = norm.cdf(peso_limite, media, desv_std)


#densidad_1 = 1 / (desv_std * np.sqrt(2 * np.pi)) * np.exp(-(x - media)**2 / (2 * desv_std ** 2))

# Cálculo del número de estudiantes que pesan menos de 75 kg
estudiantes_menos_75kg = total_estudiantes * prob_menos_75kg

print("Probabilidad de que un estudiante pese menos de 75 kg:", prob_menos_75kg)
print("Número de estudiantes que pesan menos de 75 kg:", estudiantes_menos_75kg)

# Graficar la distribución normal
x = np.linspace(media - 4 * desv_std, media + 4 * desv_std, 1000)
y = norm.pdf(x, media, desv_std)

plt.plot(x, y, 'b', linewidth=2)
plt.fill_between(x, y, where=(x <= peso_limite), color='skyblue', alpha=0.5)
plt.title('Probabilidad de que un estudiante pese menos de 75 kg. \n $\mu=70$, $\sigma=4$, X=500')
plt.xlabel('Peso (kg)')
plt.ylabel('Densidad de probabilidad')
plt.grid(True)
plt.show()
# Out:
# Probabilidad de que un estudiante pese menos de 75 kg: 0.8943502263331446
# Número de estudiantes que pesan menos de 75 kg: 447.1751131665723

# %% [markdown]
# ### Cuantos estudiantes pesan menos de 62 kg.

# %%
plt.figure(figsize=(6, 4))

# Parámetros de la distribución normal
media = 70  # Media
desv_std = 4  # Desviación estándar
total_estudiantes = 500

# VARIABLE para Cálculo de la probabilidad de que un estudiante pese menos de 75 kg
peso_limite = 62

# Primero necesitamos calcular la probabilidad de que un estudiante pese menos
# de 75 kg utilizando la función de distribución acumulativa (CDF) de la distribución normal
prob_menos_62kg = norm.cdf(peso_limite, media, desv_std)

# Cálculo del número de estudiantes que pesan menos de 75 kg
estudiantes_menos_62kg = total_estudiantes * prob_menos_62kg

print("Probabilidad de que un estudiante pese menos de 62 kg:", prob_menos_62kg)
print("Número de estudiantes que pesan menos de 75 kg:", estudiantes_menos_62kg)

# Calcular la distribución normal
x = np.linspace(media - 4 * desv_std, media + 4 * desv_std, total_estudiantes)
y = norm.pdf(x, media, desv_std)

# Graficar  la distribución normal
plt.plot(x, y, 'b', linewidth=2)
plt.fill_between(x, y, where=(x <= peso_limite), color='skyblue', alpha=0.5)
plt.title('Probabilidad de que un estudiante pese menos de 62 kg, \n $\mu=70$, $\sigma=4$, X=500')
plt.xlabel('Peso (kg)')
plt.ylabel('Densidad de probabilidad')
plt.grid(True)
plt.show()
# Out:
# Probabilidad de que un estudiante pese menos de 62 kg: 0.022750131948179195
# Número de estudiantes que pesan menos de 75 kg: 11.375065974089598

# %% [markdown]
#  ### Cuantos estudiantes pesan mas de 79 kg.

# %%
plt.figure(figsize=(6, 4))

# Parámetros de la distribución normal
media = 70  # Media
desv_std = 4  # Desviación estándar
peso_limite = 79   # Peso límite
total_estudiantes = 500

# Calculamos la probabilidad de que un estudiante pese menos o igual a 79 kg
prob_menos_79kg = norm.cdf(peso_limite, media, desv_std)

# La probabilidad de que un estudiante pese más de 79 kg es complementaria
prob_mas_79kg = 1 - prob_menos_79kg

# Calculamos el número aproximado de estudiantes que pesan más de 79 kg
estudiantes_mas_79kg = total_estudiantes * prob_mas_79kg

print("Probabilidad de que un estudiante pese más de 79 kg:", prob_mas_79kg)
print("Número aproximado de estudiantes que pesan más de 79 kg:", estudiantes_mas_79kg)

# Calcular la función de densidad de probabilidad de la distribución normal
x = np.linspace(media - 4 * desv_std, media + 4 * desv_std, total_estudiantes)
y = norm.pdf(x, media, desv_std)

plt.plot(x, y, 'b', linewidth=2)
plt.fill_between(x, y, where=(x >= peso_limite), color='skyblue', alpha=0.5)
plt.title('Probabilidad de que un estudiante pese mas de 79 Kg. \n $\mu=70$, $\sigma=4$, X=500')
plt.xlabel('Peso (kg)')
plt.ylabel('Densidad de probabilidad')
plt.grid(True)
plt.show()
# Out:
# Probabilidad de que un estudiante pese más de 79 kg: 0.012224472655044671
# Número aproximado de estudiantes que pesan más de 79 kg: 6.112236327522336

# %% [markdown]
# ## Ejercicio 3
#
# Una revision de los pesos de 500 estudiantes del ITD, evidenció que la media es de 70 kilogramos y la desviacion estandar es de 4 kilogramos. Suponiendo que los valores se distribuyen normalmente. Hallar lo siguiente:
#
# -  La probabilidad de estudiantes que pesan mas de 68 y menos de 72 kg.
# -  Cuantos estudiantes pesan mas de 68 y menos de 72 kg.

# %%
# Parámetros de la distribución normal
media = 70  # Media
desv_std = 4  # Desviación estándar

# Peso límite inferior y superior
peso_inferior = 68
peso_superior = 72

# Calculamos la probabilidad acumulada hasta el peso superior
prob_superior = norm.cdf(peso_superior, media, desv_std)

# Calculamos la probabilidad acumulada hasta el peso inferior
prob_inferior = norm.cdf(peso_inferior, media, desv_std)

# Calculamos la probabilidad de que los estudiantes pesen entre 68 y 72 kg
prob_entre_68_y_72kg = prob_superior - prob_inferior

# Calculamos el número aproximado de estudiantes que pesan entre 68 y 72 kg
total_estudiantes = 500
estudiantes_entre_68_y_72kg = total_estudiantes * prob_entre_68_y_72kg

print("Probabilidad de que un estudiante pese entre 68 y 72 kg:", prob_entre_68_y_72kg)
print("Número aproximado de estudiantes que pesan entre 68 y 72 kg:", estudiantes_entre_68_y_72kg)

# Calcular la distribución normal
x = np.linspace(media - 4 * desv_std, media + 4 * desv_std, total_estudiantes)
y = norm.pdf(x, media, desv_std)

# Graficar  la distribución normal
plt.plot(x, y, 'b', linewidth=2)
plt.fill_between(x, y, where=(x >= peso_inferior) & (x <= peso_superior), color='skyblue', alpha=0.5)
plt.title('Probabilidad de que un estudiante pese menos de 62 kg, \n $\mu=70$, $\sigma=4$, X=500')
plt.xlabel('Peso (kg)')
plt.ylabel('Densidad de probabilidad')
plt.grid(True)
plt.show()
# Out:
# Probabilidad de que un estudiante pese entre 68 y 72 kg: 0.38292492254802624
# Número aproximado de estudiantes que pesan entre 68 y 72 kg: 191.46246127401312

# %%
from scipy.stats import binom

# Parámetros de la distribución binomial
probabilidad_exito = 0.83
num_pacientes = 16

# Calcular la probabilidad de que ningún paciente sufra la enfermedad
probabilidad_ninguno_enfermo = binom.pmf(0, num_pacientes, probabilidad_exito)

print("La probabilidad de que ningún paciente sufra la enfermedad es:", probabilidad_ninguno_enfermo)
# Out:
# La probabilidad de que ningún paciente sufra la enfermedad es: 4.866119187566705e-13

# %%
from scipy.stats import binom

# Parámetros de la distribución binomial
probabilidad_exito = 0.83
num_pacientes = 16

# Calcular la probabilidad de que todos los pacientes sufran la enfermedad
probabilidad_todos_enfermos = binom.pmf(num_pacientes, num_pacientes, probabilidad_exito)

print("La probabilidad de que todos los pacientes sufran la enfermedad es:", probabilidad_todos_enfermos)
# Out:
# La probabilidad de que todos los pacientes sufran la enfermedad es: 0.0507282029895386

# %% [markdown]
# # Bibliografía
#
# - Anderson, David R., Dennis J. Sweeney, and Thomas A. Williams. 2008. Estadística Para Administración y Economía. 10th ed. Australia • Brasil • Corea • España • Estados Unidos • Japón • México • Reino Unido • Singapur: Cengage Learning,.
#
# - Mendenhall, William, Robert J. Beaver, and Barbara M. Beaver. 2006. Introducción a La Probabilidad y Estadística. 13a Edición.
#
# - Walpole, Ronald E., Raymond H. Myers, and Sharon L. Myers. 2012. Probabilidad y Estadística Para Ingeniería y Ciencias. Novena Edición. México: Pearson.
